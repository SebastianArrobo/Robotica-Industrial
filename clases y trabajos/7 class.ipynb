# %%
# %matplotlib inline

import matplotlib.pylab as plt
import numpy as np
from sympy import *
import pandas as pd
from scipy import stats
from scipy.integrate import quad

# %%
init_printing()

# %%
t=np.arange(0,np.pi,0.1)
f= lambda x: np.sin(x)
    
plt.plot(t,f(t))

# %%
quad(f,0,np.pi)#integral de la funcion f de cero a pi
# Out:
# (2.0, 2.220446049250313e-14)

# %% [markdown]
# # CAMNATAS ALEATORIAS

# %%
% matplotlib inline
